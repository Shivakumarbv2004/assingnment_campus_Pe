# %%
#QUESTION NO 6: 


# GRADE CALCULATOR PROGRAM


# Step 1: Take marks for 5 subjects
marks = []
for i in range(1, 6):
    mark = float(input(f"Enter marks for subject {i}: "))
    marks.append(mark)

# Step 2: Calculate total and percentage
total_marks = sum(marks)
percentage = total_marks / 5

# Step 3: Determine grade using percentage
if percentage >= 90:
    grade = "A+"
elif percentage >= 80:
    grade = "A"
elif percentage >= 70:
    grade = "B"
elif percentage >= 60:
    grade = "C"
elif percentage >= 50:
    grade = "D"
else:
    grade = "F"

# Step 4: Check pass/fail condition
result = "Pass" if all(mark >= 40 for mark in marks) else "Fail"

# Step 5: Display results
print("\n----- RESULT -----")
print("Total Marks      :", total_marks)
print("Percentage       :", percentage)
print("Grade            :", grade)
print("Result           :", result)
# Out:
# Enter marks for subject 1:  60
# Enter marks for subject 2:  76
# Enter marks for subject 3:  89
# Enter marks for subject 4:  90
# Enter marks for subject 5:  99
# ----- RESULT -----
# Total Marks      : 414.0
# Percentage       : 82.8
# Grade            : A
# Result           : Pass
