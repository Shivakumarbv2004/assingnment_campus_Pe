# %%
#### QUESTION NO 16:


# NUMBER GUESSING GAME


import random

# Step 1: Generate random number
secret_number = random.randint(1, 100)

# Step 2: Give 7 attempts
for attempt in range(1, 8):
    guess = int(input("Enter your guess (1-100): "))

    if guess == secret_number:
        print("Congratulations! You guessed correctly.")
        break
    elif guess < secret_number:
        print("Too Low!")
    else:
        print("Too High!")

else:
    print("Game Over! The number was", secret_number)
# Out:
# Enter your guess (1-100):  67
# Too Low!
# Enter your guess (1-100):  45325
# Too High!
# Enter your guess (1-100):  543
# Too High!
# Enter your guess (1-100):  34
# Too Low!
# Enter your guess (1-100):  56
# Too Low!
# Enter your guess (1-100):  67
# Too Low!
# Enter your guess (1-100):  23
# Too Low!
# Game Over! The number was 100
