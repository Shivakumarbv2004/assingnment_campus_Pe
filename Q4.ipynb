# %%
# -----------------------------------
# AGE CALCULATOR PROGRAM (Accurate)
# -----------------------------------

from datetime import datetime

# Step 1: Get today's date
today = datetime.today()

# Step 2: Ask user for full birth date
day = int(input("Enter birth day (DD): "))
month = int(input("Enter birth month (MM): "))
year = int(input("Enter birth year (YYYY): "))

# Step 3: Create birth date object
birth_date = datetime(year, month, day)

# Step 4: Calculate exact difference
age_days = (today - birth_date).days
age_years = age_days // 365
age_months = age_years * 12
age_hours = age_days * 24
age_minutes = age_hours * 60

years_to_100 = 100 - age_years

# Step 5: Display results
print("\n----- EXACT AGE DETAILS -----")
print("Current Age:", age_years, "years")
print("Age in Months:", age_months)
print("Age in Days:", age_days)
print("Age in Hours:", age_hours)
print("Age in Minutes:", age_minutes)
print("Years until 100:", years_to_100)
# Out:
# Enter birth day (DD):  1
# Enter birth month (MM):  1
# Enter birth year (YYYY):  2004
# ----- EXACT AGE DETAILS -----
# Current Age: 22 years
# Age in Months: 264
# Age in Days: 8088
# Age in Hours: 194112
# Age in Minutes: 11646720
# Years until 100: 78
